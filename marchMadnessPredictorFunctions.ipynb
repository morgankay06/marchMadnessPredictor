# %%
import pandas as pd
import random

# %%
teamA = Team("Duke", 0.99)
teamB = Team("UConn", 0.8)
print(teamA.name, teamB.score)
# Out:
# Duke 0.8

# %%
#find baseline strength with adjusted offensive and 
#defensive ratings
#use 10.25 as exponent according to ken pom: https://kenpom.com/blog/ratings-explanation/
#uses basketball pythagoras equation
def calc_strength_pyth (adj_o, adj_d):
    exponent = 10.25
    off_term = adj_o**exponent
    def_term = adj_d**exponent

    #how much of the team's strength is offensive
    ovr_offStrength = off_term/(off_term+def_term)
    return ovr_offStrength

# %%
#calculate the probability of team A beating team B
import random
def single_game_sim(teamA, pythA, teamB, pythB):
    
    #create a random roll
    randomRoll = random.random()

    if(randomRoll < prob_a_wins):
        print(f"Prediction: {teamA} beats {teamB} at original probability of {prob_a_wins: .2%}")
        return teamA
    else:
        print(f"Predicting upset: {teamB} beats {teamA} at original probability of {(1-prob_a_wins):.2%}")
        return teamB
